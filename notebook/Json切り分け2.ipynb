# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

train = pd.read_csv('../data/input/train.csv')
test = pd.read_csv('../data/input/test.csv')

train
# Out:
#         id                              belongs_to_collection     budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...   14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...   40000000
# 2        3                                                NaN    3300000
# 3        4                                                NaN    1200000
# 4        5                                                NaN          0
# 5        6                                                NaN    8000000
# 6        7                                                NaN   14000000
# 7        8                                                NaN          0
# 8        9  [{'id': 256377, 'name': 'The Muppet Collection...          0
# 9       10                                                NaN    6000000
# 10      11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...    1000000
# 11      12  [{'id': 48190, 'name': 'Revenge of the Nerds C...          0
# ...

# %% [markdown]
# ### production_countries

# %%
import json
import ast

train_gen = train.loc[:, 'production_countries']
test_gen = test.loc[:, 'production_countries']

#学習データ切り分け
train_gen = train_gen.to_json()
train_gen_dict = json.loads(train_gen)
iso_train_dict = {}
name_train_dict = {}

for k, v in train_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
        if len(v) >= 2 :
            iso_train_list = []
            name_train_list = []
            for i in range(len(v)) :
                iso_train_list.append(str(v[i]['iso_3166_1']))
                name_train_list.append(str(v[i]['name']))
                
            iso_train_dict[k] = ', '.join(iso_train_list)
            name_train_dict[k] = ', '.join(name_train_list)

        else:
            iso_train_dict[k] = v[0]['iso_3166_1']
            name_train_dict[k] = v[0]['name']
            
iso_train_se = pd.Series(iso_train_dict, iso_train_dict.keys(), name='production_countries_iso_3166_1')
name_train_se = pd.Series(name_train_dict, name_train_dict.keys(), name='production_countries_name')


#テストデータ切り分け
test_gen = test_gen.to_json()
test_gen_dict = json.loads(test_gen)
iso_test_dict = {}
name_test_dict = {}

for k, v in test_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
        if len(v) >= 2 :
            iso_test_list = []
            name_test_list = []
            for i in range(len(v)) :
                iso_test_list.append(str(v[i]['iso_3166_1']))
                name_test_list.append(str(v[i]['name']))
                
            iso_test_dict[k] = ', '.join(iso_test_list)
            name_test_dict[k] = ', '.join(name_test_list)

        else:
            iso_test_dict[k] = v[0]['iso_3166_1']
            name_test_dict[k] = v[0]['name']
            
iso_test_se = pd.Series(iso_test_dict, iso_test_dict.keys(), name='production_countries_iso_3166_1')
name_test_se = pd.Series(name_test_dict, name_test_dict.keys(), name='production_countries_name')

# %%
train = pd.concat([train, iso_train_se, name_train_se], axis=1)
train.drop('production_countries', inplace=True, axis=1)
train.head(3)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
# ...

# %%
train = pd.concat([test, iso_test_se, name_test_se], axis=1)
train.drop('production_countries', inplace=True, axis=1)
train.head(3)
# Out:
#      id                              belongs_to_collection  budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...       0
# 1  3002                                                NaN   88000
# 2  3003                                                NaN       0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# 2                                                NaN  tt0118556
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
# 2                en             Addicted to Love
#
# ...

# %% [markdown]
# ### spoken_languages

# %%
train_gen = train.loc[:, 'spoken_languages']
test_gen = test.loc[:, 'spoken_languages']

#学習データ切り分け
train_gen = train_gen.to_json()
train_gen_dict = json.loads(train_gen)
iso_train_dict = {}
name_train_dict = {}

for k, v in train_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
        if len(v) >= 2 :
            iso_train_list = []
            name_train_list = []
            for i in range(len(v)) :
                iso_train_list.append(str(v[i]['iso_639_1']))
                name_train_list.append(str(v[i]['name']))
                
            iso_train_dict[k] = ', '.join(iso_train_list)
            name_train_dict[k] = ', '.join(name_train_list)

        else:
            iso_train_dict[k] = v[0]['iso_639_1']
            name_train_dict[k] = v[0]['name']
            
iso_train_se = pd.Series(iso_train_dict, iso_train_dict.keys(), name='spoken_languages_iso_639_1')
name_train_se = pd.Series(name_train_dict, name_train_dict.keys(), name='spoken_languages_name')


#テストデータ切り分け
test_gen = test_gen.to_json()
test_gen_dict = json.loads(test_gen)
iso_test_dict = {}
name_test_dict = {}

for k, v in test_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
        if len(v) >= 2 :
            iso_test_list = []
            name_test_list = []
            for i in range(len(v)) :
                iso_test_list.append(str(v[i]['iso_639_1']))
                name_test_list.append(str(v[i]['name']))
                
            iso_test_dict[k] = ', '.join(iso_test_list)
            name_test_dict[k] = ', '.join(name_test_list)

        else:
            iso_test_dict[k] = v[0]['iso_639_1']
            name_test_dict[k] = v[0]['name']
            
iso_test_se = pd.Series(iso_test_dict, iso_test_dict.keys(), name='spoken_languages_iso_639_1')
name_test_se = pd.Series(name_test_dict, name_test_dict.keys(), name='spoken_languages_name')

# %%
train = pd.concat([train, iso_train_se, name_train_se], axis=1)
train.drop('spoken_languages', inplace=True, axis=1)
train.head(3)
# Out:
#      id                              belongs_to_collection  budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...       0
# 1  3002                                                NaN   88000
# 2  3003                                                NaN       0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# 2                                                NaN  tt0118556
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
# 2                en             Addicted to Love
#
# ...

# %%
test = pd.concat([test, iso_test_se, name_test_se], axis=1)
test.drop('spoken_languages', inplace=True, axis=1)
test.head(3)
# Out:
#      id                              belongs_to_collection  budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...       0
# 1  3002                                                NaN   88000
# 2  3003                                                NaN       0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# 2                                                NaN  tt0118556
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
# 2                en             Addicted to Love
#
# ...

# %% [markdown]
# ### cast

# %%
train_gen = train.loc[:, 'cast']
test_gen = test.loc[:, 'cast']

#train_gen[9]

# %%
train_gen = train.loc[:, 'cast']
test_gen = test.loc[:, 'cast']

#学習データ切り分け
train_gen = train_gen.to_json()
train_gen_dict = json.loads(train_gen)

cast_id_train_dict = {}
character_train_dict = {}
credit_id_train_dict = {}
gender_train_dict = {}
id_train_dict = {}
name_train_dict = {}
order_train_dict = {}
profile_path_train_dict = {}

for k, v in train_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
#        if len(v) >= 2 :
        cast_id_train_list = []
        character_train_list = []
        credit_id_train_list = []
        gender_train_list = []
        id_train_list = []
        name_train_list = []
        order_train_list = []
        profile_path_train_list = []
        
        for i in range(len(v)) :
            cast_id_train_list.append(str(v[i]['cast_id']))
            character_train_list.append(str(v[i]['character']))
            credit_id_train_list.append(str(v[i]['credit_id']))
            gender_train_list.append(str(v[i]['gender']))
            id_train_list.append(str(v[i]['id']))
            name_train_list.append(str(v[i]['name']))
            order_train_list.append(str(v[i]['order']))
            profile_path_train_list.append(str(v[i]['profile_path']))
                
        cast_id_train_dict[k] = ', '.join(cast_id_train_list)
        character_train_dict[k] = ', '.join(character_train_list)
        credit_id_train_dict[k] = ', '.join(credit_id_train_list)
        gender_train_dict[k] = ', '.join(gender_train_list)
        id_train_dict[k] = ', '.join(id_train_list)
        name_train_dict[k] = ', '.join(name_train_list)
        order_train_dict[k] = ', '.join(order_train_list)
        profile_path_train_dict[k] = ', '.join(profile_path_train_list)

#不要？？？
#         else:
#             cast_id_train_dict[k] = v[0]['cast_id']
#             character_train_dict[k] = v[0]['character']
#             credit_id_train_dict[k] = v[0]['credit_id']
#             gender_train_dict[k] = v[0]['gender']
#             id_train_dict[k] = v[0]['id']
#             name_train_dict[k] = v[0]['name']
#             order_train_dict[k] = v[0]['order']
#             profile_path_train_dict[k] = v[0]['profile_path']

cast_id_train_se = pd.Series(cast_id_train_dict, cast_id_train_dict.keys(), name='cast_cast_id')
character_train_se = pd.Series(character_train_dict, character_train_dict.keys(), name='cast_character')
credit_id_train_se = pd.Series(credit_id_train_dict, credit_id_train_dict.keys(), name='cast_credit_id')
gender_train_se = pd.Series(gender_train_dict, gender_train_dict.keys(), name='cast_gender')
id_train_se = pd.Series(id_train_dict, id_train_dict.keys(), name='cast_id')
name_train_se = pd.Series(name_train_dict, name_train_dict.keys(), name='cast_name')
order_train_se = pd.Series(order_train_dict, order_train_dict.keys(), name='cast_order')
profile_path_train_se = pd.Series(profile_path_train_dict, profile_path_train_dict.keys(), name='cast_profile_path')

#テストデータ切り分け
test_gen = test_gen.to_json()
test_gen_dict = json.loads(test_gen)
cast_id_test_dict = {}
character_test_dict = {}
credit_id_test_dict = {}
gender_test_dict = {}
id_test_dict = {}
name_test_dict = {}
order_test_dict = {}
profile_path_test_dict = {}

for k, v in test_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
#        if len(v) >= 2 :
        cast_id_test_list = []
        character_test_list = []
        credit_id_test_list = []
        gender_test_list = []
        id_test_list = []
        name_test_list = []
        order_test_list = []
        profile_path_test_list = []

        for i in range(len(v)) :
            cast_id_test_list.append(str(v[i]['cast_id']))
            character_test_list.append(str(v[i]['character']))
            credit_id_test_list.append(str(v[i]['credit_id']))
            gender_test_list.append(str(v[i]['gender']))
            id_test_list.append(str(v[i]['id']))
            name_test_list.append(str(v[i]['name']))
            order_test_list.append(str(v[i]['order']))
            profile_path_test_list.append(str(v[i]['profile_path']))
                
        cast_id_test_dict[k] = ', '.join(cast_id_test_list)
        character_test_dict[k] = ', '.join(character_test_list)
        credit_id_test_dict[k] = ', '.join(credit_id_test_list)
        gender_test_dict[k] = ', '.join(gender_test_list)
        id_test_dict[k] = ', '.join(id_test_list)
        name_test_dict[k] = ', '.join(name_test_list)
        order_test_dict[k] = ', '.join(order_test_list)
        profile_path_test_dict[k] = ', '.join(profile_path_test_list)

#不要？？？
#         else:
#             cast_id_test_dict[k] = v[0]['cast_id']
#             character_test_dict[k] = v[0]['character']
#             credit_id_test_dict[k] = v[0]['credit_id']
#             gender_test_dict[k] = v[0]['gender']
#             id_test_dict[k] = v[0]['id']
#             name_test_dict[k] = v[0]['name']
#             order_test_dict[k] = v[0]['order']
#             profile_path_test_dict[k] = v[0]['profile_path']

cast_id_test_se = pd.Series(cast_id_test_dict, cast_id_test_dict.keys(), name='cast_cast_id')
character_test_se = pd.Series(character_test_dict, character_test_dict.keys(), name='cast_character')
credit_id_test_se = pd.Series(credit_id_test_dict, credit_id_test_dict.keys(), name='cast_credit_id')
gender_test_se = pd.Series(gender_test_dict, gender_test_dict.keys(), name='cast_gender')
id_test_se = pd.Series(id_test_dict, id_test_dict.keys(), name='cast_id')
name_test_se = pd.Series(name_test_dict, name_test_dict.keys(), name='cast_name')
order_test_se = pd.Series(order_test_dict, order_test_dict.keys(), name='cast_order')
profile_path_test_se = pd.Series(profile_path_test_dict, profile_path_test_dict.keys(), name='cast_profile_path')

# %%
train = pd.concat([train, cast_id_train_se, character_train_se, credit_id_train_se, gender_train_se, id_train_se, name_train_se,
                  order_train_se, profile_path_train_se], axis=1)
train.drop('cast', inplace=True, axis=1)
train.head(3)
# Out:
#      id                              belongs_to_collection  budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...       0
# 1  3002                                                NaN   88000
# 2  3003                                                NaN       0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# 2                                                NaN  tt0118556
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
# 2                en             Addicted to Love
#
# ...

# %%
test = pd.concat([test, cast_id_test_se, character_test_se, credit_id_test_se, gender_test_se, id_test_se, name_test_se,
                  order_test_se, profile_path_test_se], axis=1)
test.drop('cast', inplace=True, axis=1)

# %% [markdown]
# ### crew

# %%
train_gen = train.loc[:, 'crew']
test_gen = test.loc[:, 'crew']

train_gen[0]
# Out:
# "[{'credit_id': '52fe44e7c3a368484e03d683', 'department': 'Directing', 'gender': 0, 'id': 65429, 'job': 'Director', 'name': 'Kunihiko Yuyama', 'profile_path': '/9z3LqqCMRZWyptfIZnlAdG7CnaZ.jpg'}, {'credit_id': '52fe44e7c3a368484e03d689', 'department': 'Writing', 'gender': 2, 'id': 25761, 'job': 'Writer', 'name': 'Hideki Sonoda', 'profile_path': None}]"

# %%
train_gen = train.loc[:, 'crew']
test_gen = test.loc[:, 'crew']

#学習データ切り分け
train_gen = train_gen.to_json()
train_gen_dict = json.loads(train_gen)

credit_id_train_dict = {}
department_train_dict = {}
gender_train_dict = {}
id_train_dict = {}
job_train_dict = {}
name_train_dict = {}
profile_path_train_dict = {}

for k, v in train_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
        if len(v) >= 2 :
            credit_id_train_list = []
            department_train_list = []
            gender_train_list = []
            id_train_list = []
            job_train_list = []
            name_train_list = []
            profile_path_train_list = []
            for i in range(len(v)) :
                credit_id_train_list.append(str(v[i]['credit_id']))
                department_train_list.append(str(v[i]['department']))
                gender_train_list.append(str(v[i]['gender']))
                id_train_list.append(str(v[i]['id']))
                job_train_list.append(str(v[i]['job']))
                name_train_list.append(str(v[i]['name']))
                profile_path_train_list.append(str(v[i]['profile_path']))
                

            credit_id_train_dict[k] = ', '.join(credit_id_train_list)
            department_train_dict[k] = ', '.join(department_train_list)
            gender_train_dict[k] = ', '.join(gender_train_list)
            id_train_dict[k] = ', '.join(id_train_list)
            job_train_dict[k] = ', '.join(job_train_list)
            name_train_dict[k] = ', '.join(name_train_list)
            profile_path_train_dict[k] = ', '.join(profile_path_train_list)
        else:
            credit_id_train_dict[k] = v[0]['credit_id']
            department_train_dict[k] = v[0]['department']
            gender_train_dict[k] = v[0]['gender']
            id_train_dict[k] = v[0]['id']
            job_train_dict[k] = v[0]['job']
            name_train_dict[k] = v[0]['name']
            profile_path_train_dict[k] = v[0]['profile_path']

credit_id_train_se = pd.Series(credit_id_train_dict, credit_id_train_dict.keys(), name='crew_credit_id')
department_train_se = pd.Series(department_train_dict, department_train_dict.keys(), name='crew_department')
gender_train_se = pd.Series(gender_train_dict, gender_train_dict.keys(), name='crew_gender')
id_train_se = pd.Series(id_train_dict, id_train_dict.keys(), name='crew_id')
job_train_se = pd.Series(job_train_dict, job_train_dict.keys(), name='crew_job')
name_train_se = pd.Series(name_train_dict, name_train_dict.keys(), name='crew_name')
profile_path_train_se = pd.Series(profile_path_train_dict, profile_path_train_dict.keys(), name='crew_profile_path')

#テストデータ切り分け
test_gen = test_gen.to_json()
test_gen_dict = json.loads(test_gen)

credit_id_test_dict = {}
department_test_dict = {}
gender_test_dict = {}
id_test_dict = {}
job_test_dict = {}
name_test_dict = {}
profile_path_test_dict = {}

for k, v in test_gen_dict.items() :
    if v is not None :
        k = int(k)
        v = ast.literal_eval(v)
        
        if len(v) >= 2 :
            credit_id_test_list = []
            department_test_list = []
            gender_test_list = []
            id_test_list = []
            job_test_list = []
            name_test_list = []
            profile_path_test_list = []
            for i in range(len(v)) :
                credit_id_test_list.append(str(v[i]['credit_id']))
                department_test_list.append(str(v[i]['department']))
                gender_test_list.append(str(v[i]['gender']))
                id_test_list.append(str(v[i]['id']))
                job_test_list.append(str(v[i]['job']))
                name_test_list.append(str(v[i]['name']))
                profile_path_test_list.append(str(v[i]['profile_path']))
                

            credit_id_test_dict[k] = ', '.join(credit_id_test_list)
            department_test_dict[k] = ', '.join(department_test_list)
            gender_test_dict[k] = ', '.join(gender_test_list)
            id_test_dict[k] = ', '.join(id_test_list)
            job_test_dict[k] = ', '.join(job_test_list)
            name_test_dict[k] = ', '.join(name_test_list)
            profile_path_test_dict[k] = ', '.join(profile_path_test_list)
        else:
            credit_id_test_dict[k] = v[0]['credit_id']
            department_test_dict[k] = v[0]['department']
            gender_test_dict[k] = v[0]['gender']
            id_test_dict[k] = v[0]['id']
            job_test_dict[k] = v[0]['job']
            name_test_dict[k] = v[0]['name']
            profile_path_test_dict[k] = v[0]['profile_path']

credit_id_test_se = pd.Series(credit_id_test_dict, credit_id_test_dict.keys(), name='crew_credit_id')
department_test_se = pd.Series(department_test_dict, department_test_dict.keys(), name='crew_department')
gender_test_se = pd.Series(gender_test_dict, gender_test_dict.keys(), name='crew_gender')
id_test_se = pd.Series(id_test_dict, id_test_dict.keys(), name='crew_id')
job_test_se = pd.Series(job_test_dict, job_test_dict.keys(), name='crew_job')
name_test_se = pd.Series(name_test_dict, name_test_dict.keys(), name='crew_name')
profile_path_test_se = pd.Series(profile_path_test_dict, profile_path_test_dict.keys(), name='crew_profile_path')

# %%
train = pd.concat([train, credit_id_train_se, department_train_se, gender_train_se, id_train_se, job_train_se, name_train_se,
                   profile_path_train_se], axis=1)
train.drop('crew', inplace=True, axis=1)
train.head(3)
# Out:
#      id                              belongs_to_collection  budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...       0
# 1  3002                                                NaN   88000
# 2  3003                                                NaN       0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# 2                                                NaN  tt0118556
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
# 2                en             Addicted to Love
#
# ...

# %%
test = pd.concat([test, credit_id_test_se, department_test_se, gender_test_se, id_test_se, job_test_se, name_test_se,
                   profile_path_test_se], axis=1)
test.drop('crew', inplace=True, axis=1)
test.head(3)
# Out:
#      id                              belongs_to_collection  budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...       0
# 1  3002                                                NaN   88000
# 2  3003                                                NaN       0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# 2                                                NaN  tt0118556
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
# 2                en             Addicted to Love
#
# ...
